-- %% [markdown]
-- This starts the next phase of the cleaning. We are now working with the cleaned State Regulations table, but there remain a group of contaminants in the lab results that have more than one set of units.

-- %%
SELECT  s.contaminant, 
        s.reg_units, 
        l.units
FROM    state_regulations s
    LEFT JOIN 
        lab_results l
    ON s.contaminant = l.parameter
WHERE s.reg_units <> l.units
GROUP BY s.contaminant, s.reg_units, l.units
-- Out:
-- (18 rows affected)
-- Total execution time: 00:00:00.201
-- <table><tr><th>contaminant</th><th>reg_units</th><th>units</th></tr><tr><td>Dissolved Copper</td><td>ug/L</td><td>mg/L</td></tr><tr><td>Dissolved Lead</td><td>ug/L</td><td>mg/L</td></tr><tr><td>Dissolved Selenium</td><td>ug/L</td><td>mg/L</td></tr><tr><td>Dissolved Mercury</td><td>ug/L</td><td>mg/L</td></tr><tr><td>Dissolved Barium</td><td>ug/L</td><td>mg/L</td></tr><tr><td>Dissolved Strontium</td><td>ug/L</td><td>mg/L</td></tr><tr><td>Dissolved Antimony</td><td>ug/L</td><td>mg/L</td></tr><tr><td>Dissolved Beryllium</td><td>ug/L</td><td>mg/L</td></tr><tr><td>bis(2-Ethylhexyl) phthalate</td><td>ug/L</td><td>mg/Kg</td></tr><tr><td>Dissolved Uranium</td><td>ug/L</td><td>mg/L as N</td></tr><tr><td>Dissolved Cadmium</td><td>ug/L</td><td>mg/L</td></tr><tr><td>Dissolved Arsenic</td><td>ug/L</td><td>mg/L</td></tr><tr><td>Dissolved Nitrate</td><td>mg/L as N</td><td>mg/L</td></tr><tr><td>Dissolved Aluminum</td><td>ug/L</td><td>mg/L</td></tr><tr><td>Total Chromium</td><td>ug/L</td><td>mg/L</td></tr><tr><td>Dissolved Thallium</td><td>ug/L</td><td>mg/L</td></tr><tr><td>Dissolved Nickel</td><td>ug/L</td><td>mg/L</td></tr><tr><td>Dissolved Mercury</td><td>ug/L</td><td>ng/L</td></tr></table>

-- %% [markdown]
-- Most of these are an easy fix - they are a conversion difference from mg/L to ug/L, which is a multiple of 1000. These are shown below:

-- %%
SELECT  s.contaminant, 
        s.reg_units, 
        l.units
FROM    state_regulations s
    LEFT JOIN 
        lab_results l
    ON  s.contaminant = l.parameter
WHERE   s.reg_units = 'ug/L'
    AND 
        l.units = 'mg/L'
GROUP BY s.contaminant, s.reg_units, l.units
-- Out:
-- (14 rows affected)
-- Total execution time: 00:00:00.148
-- <table><tr><th>contaminant</th><th>reg_units</th><th>units</th></tr><tr><td>Dissolved Aluminum</td><td>ug/L</td><td>mg/L</td></tr><tr><td>Dissolved Antimony</td><td>ug/L</td><td>mg/L</td></tr><tr><td>Dissolved Arsenic</td><td>ug/L</td><td>mg/L</td></tr><tr><td>Dissolved Barium</td><td>ug/L</td><td>mg/L</td></tr><tr><td>Dissolved Beryllium</td><td>ug/L</td><td>mg/L</td></tr><tr><td>Dissolved Cadmium</td><td>ug/L</td><td>mg/L</td></tr><tr><td>Dissolved Copper</td><td>ug/L</td><td>mg/L</td></tr><tr><td>Dissolved Lead</td><td>ug/L</td><td>mg/L</td></tr><tr><td>Dissolved Mercury</td><td>ug/L</td><td>mg/L</td></tr><tr><td>Dissolved Nickel</td><td>ug/L</td><td>mg/L</td></tr><tr><td>Dissolved Selenium</td><td>ug/L</td><td>mg/L</td></tr><tr><td>Dissolved Strontium</td><td>ug/L</td><td>mg/L</td></tr><tr><td>Dissolved Thallium</td><td>ug/L</td><td>mg/L</td></tr><tr><td>Total Chromium</td><td>ug/L</td><td>mg/L</td></tr></table>

-- %% [markdown]
-- Those which are not listed here are:
--
-- - bis(2-Ethylhexyl) phthalate, which has a measure in mg/Kg - which is measured in water, so can be converted the same way as the above, as 1 kg of water = 1 L of water
-- - Dissolved Uranium - this has units that make no sense at all. I can either assume that the intended was mg/L or disregard these measurements altogether
-- - Dissolved Nitrate - Many of the Nitrates were measured as mg/L. As discussed previously, these will have to be multiplied by .226 to convert to mg/L as N
-- - Dissolved Mercury has both measurements in mg/L as well as ng/L. For ng/L, I will have to divide those values by 1000.

-- %%
SELECT  s.contaminant, 
        s.reg_units, 
        l.units, 
        l.result,
    CASE 
        WHEN (s.reg_units = 'ug/L' AND l.units = 'mg/L') THEN l.result * 1000 
        WHEN l.units = 'mg/Kg' THEN l.result * 1000
        WHEN (s.contaminant = 'Dissolved Uranium' AND l.units = 'mg/L as N') THEN l.result * 1000
        WHEN (s.contaminant = 'Dissolved Nitrate' AND l.units = 'mg/L') THEN l.result * 0.226
        WHEN (s.contaminant = 'Dissolved Mercury' AND l.units = 'ng/L') THEN l.result / 1000
        ELSE l.result 
    END AS Fixed_Result

FROM    state_regulations s
    LEFT JOIN 
        lab_results l
    ON  s.contaminant = l.parameter
WHERE s.contaminant = 'Dissolved Mercury' AND l.result <> 0
-- Out:
-- (471 rows affected)
-- Total execution time: 00:00:00.116
-- <table><tr><th>contaminant</th><th>reg_units</th><th>units</th><th>result</th><th>Fixed_Result</th></tr><tr><td>Dissolved Mercury</td><td>ug/L</td><td>mg/L</td><td>0.2</td><td>200</td></tr><tr><td>Dissolved Mercury</td><td>ug/L</td><td>mg/L</td><td>0.2</td><td>200</td></tr><tr><td>Dissolved Mercury</td><td>ug/L</td><td>mg/L</td><td>0.2</td><td>200</td></tr><tr><td>Dissolved Mercury</td><td>ug/L</td><td>mg/L</td><td>0.01</td><td>10</td></tr><tr><td>Dissolved Mercury</td><td>ug/L</td><td>mg/L</td><td>0.002</td><td>2</td></tr><tr><td>Dissolved Mercury</td><td>ug/L</td><td>ng/L</td><td>0.8</td><td>0.0008</td></tr><tr><td>Dissolved Mercury</td><td>ug/L</td><td>ng/L</td><td>1.6</td><td>0.0016</td></tr><tr><td>Dissolved Mercury</td><td>ug/L</td><td>ng/L</td><td>1</td><td>0.001</td></tr><tr><td>Dissolved Mercury</td><td>ug/L</td><td>ng/L</td><td>1.1</td><td>0.0011</td></tr><tr><td>Dissolved Mercury</td><td>ug/L</td><td>ng/L</td><td>1</td><td>0.001</td></tr><tr><td>Dissolved Mercury</td><td>ug/L</td><td>ng/L</td><td>0.7</td><td>0.0007</td></tr><tr><td>Dissolved Mercury</td><td>ug/L</td><td>ng/L</td><td>1.1</td><td>0.0011</td></tr><tr><td>Dissolved Mercury</td><td>ug/L</td><td>ng/L</td><td>1.01</td><td>0.00101</td></tr><tr><td>Dissolved Mercury</td><td>ug/L</td><td>ng/L</td><td>0.9</td><td>0.0009</td></tr><tr><td>Dissolved Mercury</td><td>ug/L</td><td>ng/L</td><td>0.9</td><td>0.0009</td></tr><tr><td>Dissolved Mercury</td><td>ug/L</td><td>ng/L</td><td>0.8</td><td>0.0008</td></tr><tr><td>Dissolved Mercury</td><td>ug/L</td><td>ng/L</td><td>1.1</td><td>0.0011</td></tr><tr><td>Dissolved Mercury</td><td>ug/L</td><td>ng/L</td><td>1.01</td><td>0.00101</td></tr><tr><td>Dissolved Mercury</td><td>ug/L</td><td>ng/L</td><td>0.7</td><td>0.0007</td></tr><tr><td>Dissolved Mercury</td><td>ug/L</td><td>ng/L</td><td>0.9</td><td>0.0009</td></tr><tr><td>Dissolved Mercury</td><td>ug/L</td><td>ng/L</td><td>0.7</td><td>0.0007</td></tr><tr><td>Dissolved Mercury</td><td>ug/L</td><td>ng/L</td><td>3.9</td><td>0.0039</td></tr><tr><td>Dissolved Mercury</td><td>ug/L</td><td>ng/L</td><td>2.5</td><td>0.0025</td></tr><tr><td>Dissolved Mercury</td><td>ug/L</td><td>ng/L</td><td>2.7</td><td>0.0027</td></tr><tr><td>Dissolved Mercury</td><td>ug/L</td><td>ng/L</td><td>2.5</td><td>0.0025</td></tr><tr><td>Dissolved Mercury</td><td>ug/L</td><td>ng/L</td><td>3.4</td><td>0.0034</td></tr><tr><td>Dissolved Mercury</td><td>ug/L</td><td>ng/L</td><td>2.1</td><td>0.0021000000000000003</td></tr><tr><td>Dissolved Mercury</td><td>ug/L</td><td>ng/L</td><td>1.7</td><td>0.0017</td></tr><tr><td>Dissolved Mercury</td><td>ug/L</td><td>ng/L</td><td>1.9</td><td>0.0019</td></tr><tr><td>Dissolved Mercury</td><td>ug/L</td><td>ng/L</td><td>3</td><td>0.003</td></tr><tr><td>Dissolved Mercury</td><td>ug/L</td><td>ng/L</td><td>3.1</td><td>0.0031</td></tr><tr><td>Dissolved Mercury</td><td>ug/L</td><td>ng/L</td><td>1.3</td><td>0.0013</td></tr><tr><td>Dissolved Mercury</td><td>ug/L</td><td>ng/L</td><td>1.6</td><td>0.0016</td></tr><tr><td>Dissolved Mercury</td><td>ug/L</td><td>ng/L</td><td>2.7</td><td>0.0027</td></tr><tr><td>Dissolved Mercury</td><td>ug/L</td><td>ng/L</td><td>1.6</td><td>0.0016</td></tr><tr><td>Dissolved Mercury</td><td>ug/L</td><td>ng/L</td><td>3.6</td><td>0.0036</td></tr><tr><td>Dissolved Mercury</td><td>ug/L</td><td>ng/L</td><td>2.9</td><td>0.0029</td></tr><tr><td>Dissolved Mercury</td><td>ug/L</td><td>ng/L</td><td>2.6</td><td>0.0026</td></tr><tr><td>Dissolved Mercury</td><td>ug/L</td><td>ng/L</td><td>1.7</td><td>0.0017</td></tr><tr><td>Dissolved Mercury</td><td>ug/L</td><td>ng/L</td><td>2</td><td>0.002</td></tr><tr><td>Dissolved Mercury</td><td>ug/L</td><td>ng/L</td><td>3.1</td><td>0.0031</td></tr><tr><td>Dissolved Mercury</td><td>ug/L</td><td>ng/L</td><td>4.4</td><td>0.0044</td></tr><tr><td>Dissolved Mercury</td><td>ug/L</td><td>ng/L</td><td>1.1</td><td>0.0011</td></tr><tr><td>Dissolved Mercury</td><td>ug/L</td><td>ng/L</td><td>1.2</td><td>0.0012</td></tr><tr><td>Dissolved Mercury</td><t ...

-- %% [markdown]
-- All of the corrected values look normal except for the converted data from ng/L to ug/L.  These look at least 1000 times too low, which suggests that they may have been measured in ug/L or mg/L, and not acutally in ng/L. I want to see if these measures came from a small subset of counties or station IDs, and what test method that they used for these.
--
-- After looking into the EPA 1631 E(D) method of quantification of mercury, the minimum detectable limit is 0.2 ng/L, and the lab parameters suggest the minimum reporting limit as 0.5 ng/L. The reason these values look very low compared to many others is due to the sensitivity of the testing. It's possible that many of the 0 ug/L or 0 mg/L records had values that would have been reported at the ng/L level, but were rounded to 0 due to the low sensitivity of the assay.

-- %%
SELECT  s.contaminant, 
        s.reg_units, 
        l.units, 
        l.result,
        l.*,

    CASE 
        WHEN (s.reg_units = 'ug/L' AND l.units = 'mg/L') THEN l.result * 1000 
        WHEN l.units = 'mg/Kg' THEN l.result * 1000
        WHEN (s.contaminant = 'Dissolved Uranium' AND l.units = 'mg/L as N') THEN l.result * 1000
        WHEN (s.contaminant = 'Dissolved Nitrate' AND l.units = 'mg/L') THEN l.result * 0.226
        WHEN (s.contaminant = 'Dissolved Mercury' AND l.units = 'ng/L') THEN l.result / 1000
        ELSE l.result 
    END AS Fixed_Result

FROM    state_regulations s
    LEFT JOIN 
        lab_results l
    ON  s.contaminant = l.parameter
WHERE s.contaminant = 'Dissolved Mercury' AND l.result <> 0 AND l.units = 'ng/L'
-- Out:
-- (341 rows affected)
-- Total execution time: 00:00:00.099
-- <table><tr><th>contaminant</th><th>reg_units</th><th>units</th><th>result</th><th>station_id</th><th>station_name</th><th>full_station_name</th><th>station_number</th><th>station_type</th><th>latitude</th><th>longitude</th><th>status_</th><th>county_name</th><th>sample_code</th><th>sample_date</th><th>sample_depth</th><th>sample_depth_units</th><th>parameter</th><th>result</th><th>reporting_limit</th><th>units</th><th>method_name</th><th>Fixed_Result</th></tr><tr><td>Dissolved Mercury</td><td>ug/L</td><td>ng/L</td><td>9.9</td><td>47675</td><td>CCSB Weir North</td><td>Cache Creek Settling Basin Overflow Weir- North</td><td>A0270001</td><td>Surface Water</td><td>38.687236</td><td>121.673675</td><td>Reviewed and Validated</td><td>Yolo</td><td>EH0117B0004</td><td>2017-01-11 10:10:00.000</td><td>1.00000000</td><td>Meters</td><td>Dissolved Mercury</td><td>9.9</td><td>0.5</td><td>ng/L</td><td>EPA 1631 E (D)</td><td>0.0099</td></tr><tr><td>Dissolved Mercury</td><td>ug/L</td><td>ng/L</td><td>1.5</td><td>47675</td><td>CCSB Weir North</td><td>Cache Creek Settling Basin Overflow Weir- North</td><td>A0270001</td><td>Surface Water</td><td>38.687236</td><td>121.673675</td><td>Reviewed and Validated</td><td>Yolo</td><td>EH0317B0574</td><td>2017-03-28 08:45:00.000</td><td>1.00000000</td><td>Meters</td><td>Dissolved Mercury</td><td>1.5</td><td>0.5</td><td>ng/L</td><td>EPA 1631 E (D)</td><td>0.0015</td></tr><tr><td>Dissolved Mercury</td><td>ug/L</td><td>ng/L</td><td>1.6</td><td>47676</td><td>CCSB Weir South</td><td>Cache Creek Settling Basin Overflow Weir- South</td><td>A0270002</td><td>Surface Water</td><td>38.682525</td><td>121.673456</td><td>Reviewed and Validated</td><td>Yolo</td><td>EH0317B0385</td><td>2017-03-01 11:15:00.000</td><td>1.00000000</td><td>Meters</td><td>Dissolved Mercury</td><td>1.6</td><td>0.5</td><td>ng/L</td><td>EPA 1631 E (D)</td><td>0.0016</td></tr><tr><td>Dissolved Mercury</td><td>ug/L</td><td>ng/L</td><td>2.1</td><td>145</td><td>Toe Drain YB LISBON</td><td>Yolo Bypass Toe Drain Below Lisbon Weir</td><td>B9D82851352</td><td>Surface Water</td><td>38.4749</td><td>121.5883</td><td>Reviewed and Validated</td><td>Yolo</td><td>EH0217B0351</td><td>2017-02-16 13:55:00.000</td><td>1.00000000</td><td>Meters</td><td>Dissolved Mercury</td><td>2.1</td><td>0.5</td><td>ng/L</td><td>EPA 1631 E (D)</td><td>0.0021000000000000003</td></tr><tr><td>Dissolved Mercury</td><td>ug/L</td><td>ng/L</td><td>1.6</td><td>145</td><td>Toe Drain YB LISBON</td><td>Yolo Bypass Toe Drain Below Lisbon Weir</td><td>B9D82851352</td><td>Surface Water</td><td>38.4749</td><td>121.5883</td><td>Reviewed and Validated</td><td>Yolo</td><td>EH0417B0771</td><td>2017-04-26 16:00:00.000</td><td>1.00000000</td><td>Meters</td><td>Dissolved Mercury</td><td>1.6</td><td>0.5</td><td>ng/L</td><td>EPA 1631 E (D)</td><td>0.0016</td></tr><tr><td>Dissolved Mercury</td><td>ug/L</td><td>ng/L</td><td>1.1</td><td>47768</td><td>ShagSl Bl Stairsteps</td><td>Shag Slough Below the Stairsteps</td><td>B9S81911416</td><td>Surface Water</td><td>38.31843</td><td>121.69314</td><td>Reviewed and Validated</td><td>Yolo</td><td>EH0317B0531</td><td>2017-03-16 09:05:00.000</td><td>1.00000000</td><td>Meters</td><td>Dissolved Mercury</td><td>1.1</td><td>0.5</td><td>ng/L</td><td>EPA 1631 E (D)</td><td>0.0011</td></tr><tr><td>Dissolved Mercury</td><td>ug/L</td><td>ng/L</td><td>3.1</td><td>779</td><td>Putah Cr@Mace</td><td>Putah Cr@Mace</td><td>J06137534264208</td><td>Other</td><td>38.519</td><td>121.6951</td><td>Reviewed and Validated</td><td>Yolo</td><td>EH0316B0241</td><td>2016-03-15 18:15:00.000</td><td>1.00000000</td><td>Meters</td><td>Dissolved Mercury</td><td>3.1</td><td>0.5</td><td>ng/L</td><td>EPA 1631 E (D)</td><td>0.0031</td></tr><tr><td>Dissolved Mercury</td><td>ug/L</td><td>ng/L</td><td>2.3</td><td>47839</td><td>LibCut ds Stairsteps</td><td>Liberty Cut downstream of the Stairsteps</td><td>B9D82001400</td><td>Surface Water</td><td>38.33334</td><td>121.667308</td><td>Reviewed and Validated</td>< ...

-- %% [markdown]
-- Final Step before shifting this to Tableau for a Dashboard - I do not want to keep all of the data from the original lab results table, and I do want to include the new calculated results. I will create a new table and dataset for this analysis, and save it as a csv.

-- %%
SELECT TOP 1 * 
FROM state_regulations
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.008
-- <table><tr><th>contaminant</th><th>state_max</th><th>state_det_limit</th><th>state_health_goal</th><th>state_health_date</th><th>federal_max</th><th>federal_max_goal</th><th>reg_units</th></tr><tr><td>Dissolved Aluminum</td><td>1000</td><td>50</td><td>600</td><td>2001</td><td>NULL</td><td>NULL</td><td>ug/L</td></tr></table>

-- %% [markdown]
-- The columns from the state\_regulations table that need to be kept in the analysis:
--
-- - contaminant
-- - state\_max
-- - federal\_max
-- - reg\_units

-- %%
SELECT TOP 1 *
FROM lab_results
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.016
-- <table><tr><th>station_id</th><th>station_name</th><th>full_station_name</th><th>station_number</th><th>station_type</th><th>latitude</th><th>longitude</th><th>status_</th><th>county_name</th><th>sample_code</th><th>sample_date</th><th>sample_depth</th><th>sample_depth_units</th><th>parameter</th><th>result</th><th>reporting_limit</th><th>units</th><th>method_name</th></tr><tr><td>8135</td><td>01S04E32C001M</td><td>01S04E32C001M</td><td>01S04E32C001M</td><td>Groundwater</td><td>37.8073</td><td>121.5617</td><td>Review Status Unknown</td><td>Alameda</td><td>WDIS_0719152</td><td>1967-05-03 09:00:00.000</td><td>NULL</td><td>Feet</td><td>Conductance</td><td>3480</td><td>1</td><td>uS/cm</td><td>EPA 120.1</td></tr></table>

-- %% [markdown]
-- The columns that need to be maintained from the lab\_results table:
--
-- - station\_id
-- - station\_name
-- - station\_type
-- - latitude
-- - longitude
-- - county\_name
-- - sample\_date
-- - parameter
-- - result
-- - units
--
--
--
-- Furthermore, I don't need the unregulated data, so I'll perform the join prior to the creation of the new table

-- %%
SELECT  s.contaminant, 
        s.state_max, 
        s.federal_max,
        l.result,
        s.reg_units, 
        l.station_id,
        l.station_name,
        l.station_type, 
        l.latitude, 
        l.longitude, 
        l.county_name,  
        l.sample_date,
    CASE 
        WHEN (s.reg_units = 'ug/L' AND l.units = 'mg/L') THEN l.result * 1000 
        WHEN l.units = 'mg/Kg' THEN l.result * 1000
        WHEN (s.contaminant = 'Dissolved Uranium' AND l.units = 'mg/L as N') THEN l.result * 1000
        WHEN (s.contaminant = 'Dissolved Nitrate' AND l.units = 'mg/L') THEN l.result * 0.226
        WHEN (s.contaminant = 'Dissolved Mercury' AND l.units = 'ng/L') THEN l.result / 1000
        ELSE l.result 
    END AS Fixed_Result
FROM    state_regulations s
    LEFT JOIN 
        lab_results l
    ON  s.contaminant = l.parameter
-- Out:
-- Total execution time: 00:00:00
-- Total execution time: 00:00:00
