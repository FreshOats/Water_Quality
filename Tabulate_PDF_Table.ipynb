# %%
from tabula import read_pdf
from tabulate import tabulate
import pandas as pd

# %% [markdown]
# Using tabula to extract the tables from the pdf, but they are spread across different pages, so this will gather a list of dfs instead of a single df

# %%
df_list  = read_pdf("Data\mcls_dlrs_phgs.pdf", pages='all')

# %% [markdown]
# The codes represent the following:
# - MCL - Maximum contaminant level
# - DLR - detection limits for reporting
# - PHG - public health goals (often smells, tastes... )
# - MCLG - maximum containment level goal

# %%
len(df_list)
# Out:
# 15

# %% [markdown]
# There are 15 dataframes extracted from the pdf

# %%
df_list[0].head()
# Out:
#           Contaminant State_MCL State_DLR State_PHG PHG_Date Federal_MCL  \
# 0  Inorganic Chemical       MCL       DLR       NaN  Date of         MCL
# 1         Contaminant       NaN       NaN       NaN      PHG         NaN
# 2            Aluminum         1      0.05       0.6     2001          --
# 3            Antimony     0.006     0.006     0.001     2016       0.006
# 4             Arsenic     0.010     0.002  0.000004     2004       0.010
#
#   Federal_MCLG
# 0         MCLG
# 1          NaN
# 2           --
# 3        0.006
# 4         zero

# %%
df_list[1].head()
# Out:
#                                          Contaminant State_MCL State_DLR  \
# 0  Chromium,\rHexavalent - 0.01-\rmg/L MCL & 0.00...        --        --
# 1                                            Cyanide      0.15       0.1
# 2                                           Fluoride         2       0.1
# 3                                Mercury (inorganic)     0.002     0.001
# 4                                             Nickel       0.1      0.01
#
#   State_PHG          PHG_Date Federal_MCL Federal_MCLG
# 0   0.00002              2011          --           --
# 1      0.15              1997         0.2          0.2
# 2         1              1997         4.0          4.0
# 3    0.0012  1999\r(rev2005)*       0.002        0.002
# 4     0.012              2001          --           --

# %%
df_list[11].head()
# Out:
#                          Contaminant   State_MCL   State_DLR  State_PHG  \
# 0  Polychlorinated\rbiphenyls (PCBs)      0.0005      0.0005    0.00009
# 1                           Simazine       0.004       0.001      0.004
# 2                        Thiobencarb        0.07       0.001      0.042
# 3                          Toxaphene       0.003       0.001    0.00003
# 4           1,2,3-\rTrichloropropane  0.00000\r5  0.00000\r5  0.0000007
#
#    PHG_Date Federal_MCL  Federal_MCLG Federal\rMCLG
# 0      2007      0.0005           NaN          zero
# 1      2001       0.004           NaN         0.004
# 2      2016          --           NaN            --
# 3      2003       0.003           NaN          zero
# 4      2009          --           NaN            --

# %% [markdown]
# Notice that the list for 1 and 13 have the titles and subtitles concatenated, where as 0 has a second heading row, which does occur in the other lists.
# I don't really care about the classification of the chemicals, so I'm going to remove the subheadings and change all of the headers to be the same:
#
# - Contaminant,
# - State_MCL,
# - State_DLR, (remove)
# - State_PHG,
# - PHG_Date, (remove)
# - Federal_MCL,
# - Federal_MCLG (remove)

# %%
# This step will work for almost all tables, but there seem to be 2 that have an 8th column, which is somewhere 
# in the middle, so these will be adjusted after we have standardized naming

for df in df_list:
    df.rename(columns={df.columns[0]: "Contaminant",
                       df.columns[1]: "State_MCL",
                       df.columns[2]: "State_DLR",
                       df.columns[3]: "State_PHG",
                       df.columns[4]: "PHG_Date",
                       df.columns[5]: "Federal_MCL",
                       df.columns[6]: "Federal_MCLG"
                       }, inplace=True)

# %%
# contaminants = pd.concat(df_list, ignore_index=True)

# %%
# contaminants

# %%
# contaminants.drop(columns=[
#                     "State_DLR",
#                     "PHG_Date",
#                     "Federal_MCLG", 
#                     "Federal\rMCLG"], inplace=True)

# %% [markdown]
# After filtering the contaminants df in Views, I determined that by removing all NaN from the State_MCL will eliminate any of the cells that contained multiple lines as a byproduct of the tabulation

# %%
# contaminants_filtered = contaminants.dropna(subset=['State_MCL'], how='all')

# %%
# contaminants_filtered = contaminants_filtered.loc[contaminants_filtered.State_MCL != "MCL"]

# %%
# contaminants_filtered.reset_index(drop=True, inplace=True)

# %%
# contaminants_filtered

# %% [markdown]
# There are several rows that need to be removed that were subtitles of the different tables - I filtered the State_MCL column for all containing "MCL", as these were the headers.  This was verified with the Federal and PHG columns - all yielded the same 4 rows
# - 0 Inorganic Chemical
# - 20 Copper and Lead
# - 23 Radionuclides
# - 107 Disinfection

# %% [markdown]
# At this point, I'm noticing that some of the columns for the Federal MCL have years in them, and it isn't just from one table, so the tables will sadly have to be cleaned individually.
#
# ---

# %%
df_list[0].dropna(subset=['State_MCL'], how='all', inplace=True)
df_list[0] = df_list[0].loc[df_list[0].State_MCL != 'MCL']

# %%
df_list[0]
# Out:
#           Contaminant State_MCL State_DLR  State_PHG PHG_Date Federal_MCL  \
# 2            Aluminum         1      0.05        0.6     2001          --
# 3            Antimony     0.006     0.006      0.001     2016       0.006
# 4             Arsenic     0.010     0.002   0.000004     2004       0.010
# 5     Asbestos (MFL =     7 MFL   0.2 MFL      7 MFL     2003       7 MFL
# 9              Barium         1       0.1          2     2003           2
# 10          Beryllium     0.004     0.001      0.001     2003       0.004
# 11            Cadmium     0.005     0.001    0.00004     2006       0.005
# 12  Chromium, Total -      0.05      0.01  withdrawn     1999         0.1
#
#    Federal_MCLG
# 2            --
# 3         0.006
# 4          zero
# 5         7 MFL
# 9             2
# 10        0.004
# 11        0.005
# 12          0.1

# %%
n = 1
df_list[n].dropna(subset=['State_MCL'], how='all', inplace=True)
df_list[n] = df_list[n].loc[df_list[n].State_MCL != 'MCL']
df_list[n]
# Out:
#                                           Contaminant State_MCL State_DLR  \
# 0   Chromium,\rHexavalent - 0.01-\rmg/L MCL & 0.00...        --        --
# 1                                             Cyanide      0.15       0.1
# 2                                            Fluoride         2       0.1
# 3                                 Mercury (inorganic)     0.002     0.001
# 4                                              Nickel       0.1      0.01
# 5                           Nitrate (as nitrogen,\rN)   10 as N       0.4
# 6                                      Nitrite (as N)    1 as N       0.4
# 7                           Nitrate + Nitrite (as\rN)   10 as N        --
# 8                                         Perchlorate     0.006     0.002
# 9                                            Selenium      0.05     0.005
# 10                                           Thallium     0.002     0.001
#
#                 State_PHG          PHG_Date Federal_MCL Federal_MCLG
# 0                 0.00002              2011          --           --
# 1                    0.15              1997         0.2          0.2
# 2                       1              1997         4.0          4.0
# 3                  0.0012  1999\r(rev2005)*       0.002        0.002
# 4                   0.012              2001          --           --
# 5   45 as NO3\r(=10 as N)              2018          10           10
# 6                  1 as N              2018           1            1
# 7                 10 as N              2018          --           --
# 8                   0.001              2015          --           --
# 9                    0.03              2010        0.05         0.05
# 10                 0.0001   1999\r(rev2004)       0.002       0.0005

# %%
n = 2
df_list[n].dropna(subset=['State_MCL'], how='all', inplace=True)
df_list[n] = df_list[n].loc[df_list[n].State_MCL != 'MCL']
df_list[n]
# Out:
#   Contaminant State_MCL State_DLR State_PHG PHG_Date Federal_MCL Federal_MCLG
# 2      Copper       1.3      0.05       0.3     2008         1.3          1.3
# 3        Lead     0.015     0.005    0.0002     2009       0.015         zero

# %%
n = 3
df_list[n].dropna(subset=['State_MCL'], how='all', inplace=True)
df_list[n] = df_list[n].loc[df_list[n].State_MCL != 'MCL']
df_list[n]
# Out:
#              Contaminant State_MCL State_DLR State_PHG PHG_Date Federal_MCL  \
# 2   Gross alpha particle        15         3      none      n/a          15
# 7    Gross beta particle         4         4      none      n/a           4
# 8       activity - OEHHA   mrem/yr       NaN       NaN      NaN     mrem/yr
# 12            Radium-226        --         1      0.05     2006         NaN
# 13            Radium-228        --         1     0.019     2006         NaN
# 14  Radium-226 + Radium-         5        --        --       --           5
#
#    Federal_MCLG
# 2          zero
# 7          zero
# 8           NaN
# 12          NaN
# 13          NaN
# 14         zero

# %%
df_list[n] = df_list[n].loc[df_list[n].State_MCL != 'mrem/yr']
df_list[n]
# Out:
#              Contaminant State_MCL State_DLR State_PHG PHG_Date Federal_MCL  \
# 2   Gross alpha particle        15         3      none      n/a          15
# 7    Gross beta particle         4         4      none      n/a           4
# 12            Radium-226        --         1      0.05     2006         NaN
# 13            Radium-228        --         1     0.019     2006         NaN
# 14  Radium-226 + Radium-         5        --        --       --           5
#
#    Federal_MCLG
# 2          zero
# 7          zero
# 12          NaN
# 13          NaN
# 14         zero

# %%
n = 4
df_list[n].dropna(subset=['State_MCL'], how='all', inplace=True)
df_list[n] = df_list[n].loc[df_list[n].State_MCL != 'MCL']
df_list[n]
# Out:
#     Contaminant State_MCL State_DLR  State_PHG  PHG_Date  Federal_MCL  \
# 0  Strontium-90         8         2       0.35       NaN         2006
# 1       Tritium  "20,000"   "1,000"     400.00       NaN         2006
# 2       Uranium        20         1       0.43       NaN         2001
#
#   Federal_MCLG Federal\rMCLG
# 0           --            --
# 1           --            --
# 2      30 μg/L          zero

# %% [markdown]
# Note: IN the above table, there is an extra column inserted where PHG_Date should be, and the values are all shifted over, this will have to be adjusted

# %%
df_list[n].drop(columns='PHG_Date', inplace=True)
df_list[n].rename(columns={'Federal_MCL': 'PHG_Date', 
                            'Federal_MCLG': 'Federal_MCL', 
                            'Federal\rMCLG': 'Federal_MCLG'}, inplace=True)
df_list[n]
# Out:
#     Contaminant State_MCL State_DLR  State_PHG  PHG_Date Federal_MCL  \
# 0  Strontium-90         8         2       0.35      2006          --
# 1       Tritium  "20,000"   "1,000"     400.00      2006          --
# 2       Uranium        20         1       0.43      2001     30 μg/L
#
#   Federal_MCLG
# 0           --
# 1           --
# 2         zero

# %% [markdown]
# Now the above matches the others

# %%
n = 5
df_list[n].dropna(subset=['State_MCL'], how='all', inplace=True)
df_list[n] = df_list[n].loc[df_list[n].State_MCL != 'MCL']
df_list[n]
# Out:
#                        Contaminant  State_MCL  State_DLR  State_PHG  \
# 0                          Benzene     0.0010     0.0005    0.00015
# 1             Carbon tetrachloride     0.0005     0.0005    0.00010
# 2              1,2-Dichlorobenzene     0.6000     0.0005    0.60000
# 3    1,4-Dichlorobenzene (p-\rDCB)     0.0050     0.0005    0.00600
# 4    1,1-Dichloroethane\r(1,1-DCA)     0.0050     0.0005    0.00300
# 5    1,2-Dichloroethane\r(1,2-DCA)     0.0005     0.0005    0.00040
# 6  1,1-Dichloroethylene\r(1,1-DCE)     0.0060     0.0005    0.01000
#
#           PHG_Date Federal_MCL Federal_MCLG
# 0             2001       0.005         zero
# 1             2000       0.005         zero
# 2  1997\r(rev2009)         0.6          0.6
# 3             1997       0.075        0.075
# 4             2003          --           --
# 5  1999\r(rev2005)       0.005         zero
# 6             1999       0.007        0.007

# %%
n = 6
df_list[n].dropna(subset=['State_MCL'], how='all', inplace=True)
df_list[n] = df_list[n].loc[df_list[n].State_MCL != 'MCL']
df_list[n]
# Out:
#                               Contaminant  State_MCL  State_DLR  State_PHG  \
# 0                cis-1,2-Dichloroethylene     0.0060     0.0005    0.01300
# 1            trans-1,2-\rDichloroethylene     0.0100     0.0005    0.05000
# 2   Dichloromethane\r(Methylene chloride)     0.0050     0.0005    0.00400
# 3                     1,2-Dichloropropane     0.0050     0.0005    0.00050
# 4                     1,3-Dichloropropene     0.0005     0.0005    0.00020
# 5                            Ethylbenzene     0.3000     0.0005    0.30000
# 6     Methyl tertiary butyl\rether (MTBE)     0.0130     0.0030    0.01300
# 7                       Monochlorobenzene     0.0700     0.0005    0.07000
# 8                                 Styrene     0.1000     0.0005    0.00050
# 9             1,1,2,2-\rTetrachloroethane     0.0010     0.0005    0.00010
# 10             Tetrachloroethylene\r(PCE)     0.0050     0.0005    0.00006
# 11                                Toluene     0.1500     0.0005    0.15000
# 12                 1,2,4-Trichlorobenzene     0.0050     0.0005    0.00500
#
#            PHG_Date Federal_MCL Federal_MCLG
# 0              2018        0.07         0.07
# 1              2018         0.1          0.1
# 2              2000       0.005         zero
# 3              1999       0.005         zero
# 4   1999\r(rev2006)          --           --
# 5              1997         0.7          0.7
# 6              1999          --           --
# 7              2014         0.1          0.1
# 8              2010         0.1          0.1
# 9              2003         0.1          0.1
# 10             2001       0.005         zero
# 11             1999           1            1
# 12             1999        0.07         0.07

# %%
n = 7
df_list[n].dropna(subset=['State_MCL'], how='all', inplace=True)
df_list[n] = df_list[n].loc[df_list[n].State_MCL != 'MCL']
df_list[n]
# Out:
#                                          Contaminant  State_MCL  State_DLR  \
# 0                 1,1,1-Trichloroethane\r(1,1,1-TCA)     0.2000        NaN
# 1                 1,1,2-Trichloroethane\r(1,1,2-TCA)     0.0050        NaN
# 2                            Trichloroethylene (TCE)     0.0050        NaN
# 3                 Trichlorofluoromethane\r(Freon 11)     0.1500        NaN
# 4  "1,1,2-Trichloro-1,2,2-\rTrifluoroethane (Freo...     1.2000        NaN
# 5                                     Vinyl chloride     0.0005        NaN
# 6                                            Xylenes     1.7500        NaN
#
#    State_PHG  PHG_Date      Federal_MCL Federal_MCLG Federal\rMCLG
# 0     0.0005   1.00000             2006          0.2           0.2
# 1     0.0005   0.00030             2006        0.005         0.003
# 2     0.0005   0.00170             2009        0.005          zero
# 3     0.0050   1.30000             2014           --            --
# 4     0.0100   4.00000  1997\r(rev2011)           --            --
# 5     0.0005   0.00005             2000        0.002          zero
# 6     0.0005   1.80000             1997           10            10

# %% [markdown]
# This list has the same issue as 4, but the State_DLR is the row that needs removal

# %%
n = 8
df_list[n].dropna(subset=['State_MCL'], how='all', inplace=True)
df_list[n] = df_list[n].loc[df_list[n].State_MCL != 'MCL']
df_list[n]
# Out:
#   Contaminant  State_MCL  State_DLR  State_PHG         PHG_Date Federal_MCL  \
# 0    Alachlor      0.002     0.0010    0.00400             1997       0.002
# 1    Atrazine      0.001     0.0005    0.00015             1999       0.003
# 2    Bentazon      0.018     0.0020    0.20000  1999\r(rev2009)          --
#
#   Federal_MCLG
# 0         zero
# 1        0.003
# 2           --

# %%
n = 9
df_list[n].dropna(subset=['State_MCL'], how='all', inplace=True)
df_list[n] = df_list[n].loc[df_list[n].State_MCL != 'MCL']
df_list[n]
# Out:
#                                    Contaminant  State_MCL  State_DLR  \
# 0                               Benzo(a)pyrene     0.0002    0.00010
# 1                                   Carbofuran     0.0180    0.00500
# 2                                    Chlordane     0.0001    0.00010
# 3                                      Dalapon     0.2000    0.01000
# 4        1,2-Dibromo-3-\rchloropropane\r(DBCP)     0.0002    0.00001
# 5   2,4-\rDichlorophenoxyaceti\rc acid (2,4-D)     0.0700    0.01000
# 6                    Di(2-\rethylhexyl)adipate     0.4000    0.00500
# 7          Di(2-\rethylhexyl)phthalate\r(DEHP)     0.0040    0.00300
# 8                                      Dinoseb     0.0070    0.00200
# 9                                       Diquat     0.0200    0.00400
# 10                                    Endothal     0.1000    0.04500
#
#     State_PHG         PHG_Date  Federal_MCL Federal_MCLG
# 0    0.000007             2010       0.0002         zero
# 1    0.000700             2016       0.0400         0.04
# 2    0.000030  1997\r(rev2006)       0.0020         zero
# 3    0.790000  1997\r(rev2009)       0.2000          0.2
# 4    0.000003             2020       0.0002         zero
# 5    0.020000             2009       0.0700         0.07
# 6    0.200000             2003       0.4000          0.4
# 7    0.012000             1997       0.0060         zero
# 8    0.014000  1997\r(rev2010)       0.0070        0.007
# 9    0.006000             2016       0.0200         0.02
# 10   0.094000             2014       0.1000          0.1

# %%
n = 10
df_list[n].dropna(subset=['State_MCL'], how='all', inplace=True)
df_list[n] = df_list[n].loc[df_list[n].State_MCL != 'MCL']
df_list[n]
# Out:
#                     Contaminant  State_MCL  State_DLR  State_PHG  \
# 0                        Endrin    0.00200    0.00010   0.000300
# 1     Ethylene dibromide\r(EDB)    0.00005    0.00002   0.000010
# 2                    Glyphosate    0.70000    0.02500   0.900000
# 3                    Heptachlor    0.00001    0.00001   0.000008
# 4            Heptachlor epoxide    0.00001    0.00001   0.000006
# 5             Hexachlorobenzene    0.00100    0.00050   0.000030
# 6   Hexachlorocyclopent\radiene    0.05000    0.00100   0.002000
# 7                       Lindane    0.00020    0.00020   0.000032
# 8                  Methoxychlor    0.03000    0.01000   0.000090
# 9                      Molinate    0.02000    0.00200   0.001000
# 10                       Oxamyl    0.05000    0.02000   0.026000
# 11            Pentachlorophenol    0.00100    0.00020   0.000300
# 12                     Picloram    0.50000    0.00100   0.166000
#
#            PHG_Date Federal_MCL Federal_MCLG
# 0              2016       0.002        0.002
# 1              2003   0.0000\r5         zero
# 2              2007         0.7          0.7
# 3              1999      0.0004         zero
# 4              1999      0.0002         zero
# 5              2003       0.001         zero
# 6              2014        0.05         0.05
# 7   1999\r(rev2005)      0.0002       0.0002
# 8              2010        0.04         0.04
# 9              2008          --           --
# 10             2009         0.2          0.2
# 11             2009       0.001         zero
# 12             2016         0.5          0.5

# %%
n = 11
df_list[n].dropna(subset=['State_MCL'], how='all', inplace=True)
df_list[n] = df_list[n].loc[df_list[n].State_MCL != 'MCL']
df_list[n]
# Out:
#                          Contaminant   State_MCL   State_DLR  State_PHG  \
# 0  Polychlorinated\rbiphenyls (PCBs)      0.0005      0.0005    0.00009
# 1                           Simazine       0.004       0.001      0.004
# 2                        Thiobencarb        0.07       0.001      0.042
# 3                          Toxaphene       0.003       0.001    0.00003
# 4           1,2,3-\rTrichloropropane  0.00000\r5  0.00000\r5  0.0000007
# 5             2,3,7,8-TCDD\r(dioxin)      3x10-8      5x10-9    5x10-11
# 6                  2,4,5-TP (Silvex)        0.05       0.001      0.003
#
#    PHG_Date Federal_MCL  Federal_MCLG Federal\rMCLG
# 0      2007      0.0005           NaN          zero
# 1      2001       0.004           NaN         0.004
# 2      2016          --           NaN            --
# 3      2003       0.003           NaN          zero
# 4      2009          --           NaN            --
# 5      2010      3x10-8           NaN          zero
# 6      2014        0.05           NaN          0.05

# %% [markdown]
# The above table here shifted in a different place from the last shifted table

# %%
df_list[n].drop(columns='Federal_MCLG', inplace=True)
df_list[n].rename(columns={'Federal\rMCLG': 'Federal_MCLG'}, inplace=True)
df_list[n]
# Out:
#                          Contaminant   State_MCL   State_DLR  State_PHG  \
# 0  Polychlorinated\rbiphenyls (PCBs)      0.0005      0.0005    0.00009
# 1                           Simazine       0.004       0.001      0.004
# 2                        Thiobencarb        0.07       0.001      0.042
# 3                          Toxaphene       0.003       0.001    0.00003
# 4           1,2,3-\rTrichloropropane  0.00000\r5  0.00000\r5  0.0000007
# 5             2,3,7,8-TCDD\r(dioxin)      3x10-8      5x10-9    5x10-11
# 6                  2,4,5-TP (Silvex)        0.05       0.001      0.003
#
#    PHG_Date Federal_MCL Federal_MCLG
# 0      2007      0.0005         zero
# 1      2001       0.004        0.004
# 2      2016          --           --
# 3      2003       0.003         zero
# 4      2009          --           --
# 5      2010      3x10-8         zero
# 6      2014        0.05         0.05

# %%
n = 12
df_list[n].dropna(subset=['State_MCL'], how='all', inplace=True)
df_list[n] = df_list[n].loc[df_list[n].State_MCL != 'MCL']
df_list[n]
# Out:
#              Contaminant State_MCL State_DLR State_PHG PHG_Date Federal_MCL  \
# 0  Total Trihalomethanes     0.080        --        --       --       0.080
# 1   Bromodichloromethane        --    0.0010   0.00006     2020          --
# 2              Bromoform        --    0.0010    0.0005     2020          --
#
#   Federal_MCLG
# 0           --
# 1         zero
# 2         zero

# %%
n = 13
df_list[n].dropna(subset=['State_MCL'], how='all', inplace=True)
df_list[n] = df_list[n].loc[df_list[n].State_MCL != 'MCL']
df_list[n]
# Out:
#                        Contaminant State_MCL State_DLR State_PHG PHG_Date  \
# 0                       Chloroform        --    0.0010    0.0004     2020
# 1             Dibromochloromethane        --    0.0010    0.0001     2020
# 2  Haloacetic Acids (five)\r(HAA5)     0.060        --        --       --
# 3            Monochloroacetic Acid        --    0.0020     0.053     2022
# 4              Dichloroacetic Acid        --    0.0010    0.0002     2022
# 5             Trichloroacetic Acid        --    0.0010    0.0001     2022
# 6             Monobromoacetic Acid        --    0.0010     0.025     2022
# 7               Dibromoacetic Acid        --    0.0010   0.00003     2022
# 8                          Bromate     0.010  0.0050**    0.0001     2009
# 9                         Chlorite       1.0     0.020      0.05     2009
#
#   Federal_MCL Federal_MCLG
# 0          --         0.07
# 1          --         0.06
# 2       0.060           --
# 3          --         0.07
# 4          --         zero
# 5          --         0.02
# 6          --           --
# 7          --           --
# 8        0.01         zero
# 9           1          0.8

# %%
n = 14
df_list[n].dropna(subset=['State_MCL'], how='all', inplace=True)
df_list[n] = df_list[n].loc[df_list[n].State_MCL != 'MCL']
df_list[n]
# Out:
#               Contaminant State_MCL State_DLR  State_PHG PHG_Date Federal_MCL  \
# 3  N-Nitrosodimethylamine        --        --   0.000003     2006          --
#
#   Federal_MCLG
# 3           --

# %% [markdown]
# Now that all of the rows have the correct columns with all the garbage removed, we can concatenate the tables

# %%
contaminants = pd.concat(df_list, ignore_index=True)

# %%
contaminants
# Out:
#                 Contaminant State_MCL State_DLR State_PHG PHG_Date  \
# 0                  Aluminum         1      0.05       0.6     2001
# 1                  Antimony     0.006     0.006     0.001     2016
# 2                   Arsenic     0.010     0.002  0.000004     2004
# 3           Asbestos (MFL =     7 MFL   0.2 MFL     7 MFL     2003
# 4                    Barium         1       0.1         2     2003
# ..                      ...       ...       ...       ...      ...
# 99     Monobromoacetic Acid        --    0.0010     0.025     2022
# 100      Dibromoacetic Acid        --    0.0010   0.00003     2022
# 101                 Bromate     0.010  0.0050**    0.0001     2009
# 102                Chlorite       1.0     0.020      0.05     2009
# 103  N-Nitrosodimethylamine        --        --  0.000003     2006
#
#     Federal_MCL Federal_MCLG Federal\rMCLG
# 0            --           --           NaN
# 1         0.006        0.006           NaN
# 2         0.010         zero           NaN
# 3         7 MFL        7 MFL           NaN
# 4             2            2           NaN
# ..          ...          ...           ...
# 99           --           --           NaN
# 100          --           --           NaN
# 101        0.01         zero           NaN
# 102           1          0.8           NaN
# 103          --           --           NaN
#
# [104 rows x 8 columns]

# %% [markdown]
# So the table now only has the values of the actual contaminants. Next steps:
#
# 1. Per the documentation, all values are in mg/L unless otherwise noted, this is NOT the case with the actual measurements from the Water Data
# 2. There are problematic rows that have different units:
#     - Asbestos (MFL=million fibers per liter; for fibers >10 microns long)
#     - Nitrate, Nitrite, and Nitrate + Nitrite have weird conversion factors - need to coordinate these with the database
#     - Gross beta particle activity - mrem/yr
#     - Tritium is in quotation marks with comma separators
#     - Uranium is in ug/L

# %%
def Decontaminate(df_list):
    index = 0
    for df in df_list:
        df.rename(columns={df.columns[0]: "Contaminant",
                           df.columns[1]: "State_MCL",
                           df.columns[2]: "State_DLR",
                           df.columns[3]: "State_PHG",
                           df.columns[4]: "PHG_Date",
                           df.columns[5]: "Federal_MCL",
                           df.columns[6]: "Federal_MCLG"
                           }, inplace=True)
        df.dropna(subset=['State_MCL'], how='all', inplace=True)
        df = df.loc[df.State_MCL != 'MCL']
        df = df.loc[df.State_MCL != 'mrem/yr']

        # if index == 4:
        #     df.drop(columns='PHG_Date', inplace=True)
        #     df.rename(columns={'Federal_MCL': 'PHG_Date',
        #                        'Federal_MCLG': 'Federal_MCL',
        #                        'Federal\rMCLG': 'Federal_MCLG'}, inplace=True)
        #     index += 1
        #     return df
        # elif index == 7:
        #     df.drop(columns='State_DLR', inplace=True)
        #     df.rename(columns={'State_PHG': 'State_DLR',
        #                        'PHG_Date': 'State_PHG',
        #                        'Federal_MCL': 'PHG_Date',
        #                        'Federal_MCLG': 'Federal_MCL',
        #                        'Federal\rMCLG': 'Federal_MCLG'}, inplace=True)
        #     index += 1
        #     return df
        # elif index == 11:
        #     df.drop(columns='Federal_MCLG', inplace=True)
        #     df.rename(columns={'Federal\rMCLG': 'Federal_MCLG'}, inplace=True)
        #     index += 1
        #     return df
        # else:
        #     index += 1
        #     return df
        
    df_concat = pd.concat(df_list, ignore_index=True)
    return df_concat

# %%
def Decontaminate_Labels(df_list):
    for df in df_list:
        df.rename(columns={df.columns[0]: "Contaminant",
                        df.columns[1]: "State_MCL",
                        df.columns[2]: "State_DLR",
                        df.columns[3]: "State_PHG",
                        df.columns[4]: "PHG_Date",
                        df.columns[5]: "Federal_MCL",
                        df.columns[6]: "Federal_MCLG"
                        }, inplace=True)
    return df_list
        

def Decontaminate_Rows(df_list):
    for n in range(len(df_list)):
        df_list[n].dropna(subset=['State_MCL'], how='all', inplace=True)
        df_list[n] = df_list[n].loc[df_list[n].State_MCL != 'MCL']
        df_list[n] = df_list[n].loc[df_list[n].State_MCL != 'mrem/yr']
    return df_list


def Decontaminate_Lists(df_list): 
    for n in range(len(df_list)):
        if n == 4:
            df_list[n].drop(columns='PHG_Date', inplace=True)
            df_list[n].rename(columns={'Federal_MCL': 'PHG_Date',
                            'Federal_MCLG': 'Federal_MCL',
                            'Federal\rMCLG': 'Federal_MCLG'}, inplace=True)
        elif n == 7:
            df_list[n].drop(columns='State_DLR', inplace=True)
            df_list[n].rename(columns={'State_PHG': 'State_DLR',
                            'PHG_Date': 'State_PHG',
                            'Federal_MCL': 'PHG_Date',
                            'Federal_MCLG': 'Federal_MCL',
                            'Federal\rMCLG': 'Federal_MCLG'}, inplace=True)
        elif n == 11:
            df_list[n].drop(columns='Federal_MCLG', inplace=True)
            df_list[n].rename(columns={'Federal\rMCLG': 'Federal_MCLG'}, inplace=True)
    return df_list


def Decontaminate(filename):
    df_list = read_pdf(filename, pages='all')
    Decontaminate_Labels(df_list)
    Decontaminate_Rows(df_list)
    Decontaminate_Lists(df_list)
    df_concat = pd.concat(df_list, ignore_index=True)
    return df_concat

# %%
test = Decontaminate_Labels(df_list)

# %%
test[0]
# Out:
#                   Contaminant State_MCL State_DLR  State_PHG PHG_Date  \
# 0          Inorganic Chemical       MCL       DLR        NaN  Date of
# 1                 Contaminant       NaN       NaN        NaN      PHG
# 2                    Aluminum         1      0.05        0.6     2001
# 3                    Antimony     0.006     0.006      0.001     2016
# 4                     Arsenic     0.010     0.002   0.000004     2004
# 5             Asbestos (MFL =     7 MFL   0.2 MFL      7 MFL     2003
# 6   million fibers per liter;       NaN       NaN        NaN      NaN
# 7              for fibers >10       NaN       NaN        NaN      NaN
# 8               microns long)       NaN       NaN        NaN      NaN
# 9                      Barium         1       0.1          2     2003
# 10                  Beryllium     0.004     0.001      0.001     2003
# 11                    Cadmium     0.005     0.001    0.00004     2006
# 12          Chromium, Total -      0.05      0.01  withdrawn     1999
# 13         OEHHA withdrew the       NaN       NaN  Nov. 2001      NaN
# 14            0.0025-mg/L PHG       NaN       NaN        NaN      NaN
#
#    Federal_MCL Federal_MCLG
# 0          MCL         MCLG
# 1          NaN          NaN
# 2           --           --
# 3        0.006        0.006
# 4        0.010         zero
# 5        7 MFL        7 MFL
# 6          NaN          NaN
# 7          NaN          NaN
# 8          NaN          NaN
# 9            2            2
# 10       0.004        0.004
# 11       0.005        0.005
# 12         0.1          0.1
# 13         NaN          NaN
# 14         NaN          NaN

# %%
test2=Decontaminate_Rows(test)

# %%
test2[14]
# Out:
#               Contaminant State_MCL State_DLR  State_PHG PHG_Date Federal_MCL  \
# 3  N-Nitrosodimethylamine        --        --   0.000003     2006          --
#
#   Federal_MCLG
# 3           --

# %%
filename = "Data\mcls_dlrs_phgs.pdf"
df_list = read_pdf(filename, pages='all')

# %%
Decontaminate(filename)
# Out:
#                 Contaminant State_MCL State_DLR State_PHG PHG_Date  \
# 0                  Aluminum         1      0.05       0.6     2001
# 1                  Antimony     0.006     0.006     0.001     2016
# 2                   Arsenic     0.010     0.002  0.000004     2004
# 3           Asbestos (MFL =     7 MFL   0.2 MFL     7 MFL     2003
# 4                    Barium         1       0.1         2     2003
# ..                      ...       ...       ...       ...      ...
# 99     Monobromoacetic Acid        --    0.0010     0.025     2022
# 100      Dibromoacetic Acid        --    0.0010   0.00003     2022
# 101                 Bromate     0.010  0.0050**    0.0001     2009
# 102                Chlorite       1.0     0.020      0.05     2009
# 103  N-Nitrosodimethylamine        --        --  0.000003     2006
#
#     Federal_MCL Federal_MCLG
# 0            --           --
# 1         0.006        0.006
# 2         0.010         zero
# 3         7 MFL        7 MFL
# 4             2            2
# ..          ...          ...
# 99           --           --
# 100          --           --
# 101        0.01         zero
# 102           1          0.8
# 103          --           --
#
# [104 rows x 7 columns]

# %%
from Decontaminate import Decontaminate

# %%
Decontaminate(filename)
# Out:
#                 Contaminant State_MCL State_DLR State_PHG PHG_Date  \
# 0                  Aluminum         1      0.05       0.6     2001
# 1                  Antimony     0.006     0.006     0.001     2016
# 2                   Arsenic     0.010     0.002  0.000004     2004
# 3           Asbestos (MFL =     7 MFL   0.2 MFL     7 MFL     2003
# 4                    Barium         1       0.1         2     2003
# ..                      ...       ...       ...       ...      ...
# 99     Monobromoacetic Acid        --    0.0010     0.025     2022
# 100      Dibromoacetic Acid        --    0.0010   0.00003     2022
# 101                 Bromate     0.010  0.0050**    0.0001     2009
# 102                Chlorite       1.0     0.020      0.05     2009
# 103  N-Nitrosodimethylamine        --        --  0.000003     2006
#
#     Federal_MCL Federal_MCLG
# 0            --           --
# 1         0.006        0.006
# 2         0.010         zero
# 3         7 MFL        7 MFL
# 4             2            2
# ..          ...          ...
# 99           --           --
# 100          --           --
# 101        0.01         zero
# 102           1          0.8
# 103          --           --
#
# [104 rows x 7 columns]
