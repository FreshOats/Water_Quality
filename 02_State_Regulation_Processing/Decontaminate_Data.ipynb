# %%
from Decontaminate import Decontaminate
import numpy as np
import pandas as pd

# %%
filename = 'Data/mcls_dlrs_phgs.pdf'
new_file = 'Data/state_regulations.csv'

# %%
from tabula import read_pdf
from tabulate import tabulate
import pandas as pd
df_list = read_pdf(filename, pages='all')

# %%
df_list[1]
# Out:
#      State Regulated\rInorganic Chemical\rContaminant State\rMCL State\rDLR  \
# 0   Chromium,\rHexavalent - 0.01-\rmg/L MCL & 0.00...         --         --
# 1                                             Cyanide       0.15        0.1
# 2                                            Fluoride          2        0.1
# 3                                 Mercury (inorganic)      0.002      0.001
# 4                                              Nickel        0.1       0.01
# 5                           Nitrate (as nitrogen,\rN)    10 as N        0.4
# 6                                      Nitrite (as N)     1 as N        0.4
# 7                           Nitrate + Nitrite (as\rN)    10 as N         --
# 8                                         Perchlorate      0.006      0.002
# 9                                            Selenium       0.05      0.005
# 10                                           Thallium      0.002      0.001
#
#                 State PHG State\rDate of\rPHG Federal\rMCL Federal\rMCLG
# 0                 0.00002                2011           --            --
# 1                    0.15                1997          0.2           0.2
# 2                       1                1997          4.0           4.0
# 3                  0.0012    1999\r(rev2005)*        0.002         0.002
# 4                   0.012                2001           --            --
# 5   45 as NO3\r(=10 as N)                2018           10            10
# 6                  1 as N                2018            1             1
# 7                 10 as N                2018           --            --
# 8                   0.001                2015           --            --
# 9                    0.03                2010         0.05          0.05
# 10                 0.0001     1999\r(rev2004)        0.002        0.0005

# %%
df_list[11]
# Out:
#   State Regulated\rNon-Volatile\rSynthetic Organic\rContaminants  State\rMCL  \
# 0                  Polychlorinated\rbiphenyls (PCBs)                  0.0005
# 1                                           Simazine                   0.004
# 2                                        Thiobencarb                    0.07
# 3                                          Toxaphene                   0.003
# 4                           1,2,3-\rTrichloropropane              0.00000\r5
# 5                             2,3,7,8-TCDD\r(dioxin)                  3x10-8
# 6                                  2,4,5-TP (Silvex)                    0.05
#
#    State\rDLR  State PHG  State\rDate of\rPHG Federal\rMCL  Unnamed: 0  \
# 0      0.0005    0.00009                 2007       0.0005         NaN
# 1       0.001      0.004                 2001        0.004         NaN
# 2       0.001      0.042                 2016           --         NaN
# 3       0.001    0.00003                 2003        0.003         NaN
# 4  0.00000\r5  0.0000007                 2009           --         NaN
# 5      5x10-9    5x10-11                 2010       3x10-8         NaN
# 6       0.001      0.003                 2014         0.05         NaN
#
#   Federal\rMCLG
# 0          zero
# 1         0.004
# 2            --
# 3          zero
# 4            --
# 5          zero
# 6          0.05

# %%
Decontaminate(filename).head(50)
# Out:
#                        Contaminant  State_MCL  State_DLR  State_PHG PHG_Date  \
# 0               Dissolved Aluminum    1000.00       50.0    600.000     2001
# 1               Dissolved Antimony       6.00        6.0      1.000     2016
# 2                Dissolved Arsenic      10.00        2.0      0.004     2004
# 3             Asbestos, Chrysotile       7.00        0.2      7.000     2003
# 4                 Dissolved Barium    1000.00      100.0   2000.000     2003
# 5              Dissolved Beryllium       4.00        1.0      1.000     2003
# 6                Dissolved Cadmium       5.00        1.0      0.040     2006
# 7                   Total Chromium      50.00       10.0        NaN     1999
# 8                          Cyanide       0.15        0.1      0.150     1997
# 9               Dissolved Fluoride       2.00        0.1      1.000     1997
# 10               Dissolved Mercury       2.00        1.0      1.200     2005
# 11                Dissolved Nickel     100.00       10.0     12.000     2001
# 12               Dissolved Nitrate      10.00      400.0     45.000     2018
# 13               Dissolved Nitrite       1.00      400.0      1.000     2018
# 14     Dissolved Nitrate + Nitrite      10.00        NaN     10.000     2018
# 15                     Perchlorate       6.00        2.0      1.000     2015
# 16              Dissolved Selenium      50.00        5.0     30.000     2010
# 17              Dissolved Thallium       2.00        1.0      0.100     2004
# 18                Dissolved Copper    1300.00       50.0    300.000     2008
# 19                  Dissolved Lead      15.00        5.0      0.200     2009
# 20            Gross Alpha Particle      22.50        4.5        NaN      NaN
# 21             Gross Beta Particle       4.00        4.0        NaN      NaN
# 22         Radium-226 + Radium-228       7.50        NaN        NaN      NaN
# 23             Dissolved Strontium      12.00        3.0      0.525     2006
# 24                         Tritium   30000.00     1500.0    600.000     2006
# 25               Dissolved Uranium      20.00        1.0      0.430     2001
# 26                         Benzene       1.00        0.5      0.150     2001
# 27            Carbon tetrachloride       0.50        0.5      0.100     2000
# 28             1,2-Dichlorobenzene     600.00        0.5    600.000     2009
# 29             1,4-Dichlorobenzene       5.00        0.5      6.000     1997
# 30              1,1-Dichloroethane       5.00        0.5      3.000     2003
# 31              1,2-Dichloroethane       0.50        0.5      0.400     2005
# 32              1,1-Dichloroethene       6.00        0.5     10.000     1999
# 33          cis-1,2-Dichloroethene       6.00        0.5     13.000     2018
# 34        trans-1,2-Dichloroethene      10.00        0.5     50.000     2018
# 35              Methylene chloride       5.00        0.5      4.000     2000
# 36             1,2-Dichloropropane       5.00        0.5      0.500     1999
# 37         cis-1,3-Dichloropropene       0.50        0.5      0.200     2006
# 38                    Ethylbenzene     300.00        0.5    300.000     1997
# 39  Methyl tert-butyl ether (MTBE)      13.00        3.0     13.000     1999
# 40                   Chlorobenzene      70.00        0.5     70.000     2014
# 41                         Styrene     100.00        0.5      0.500     2010
# 42       1,1,2,2-Tetrachloroethane       1.00        0.5      0.100     2003
# 43               Tetrachloroethene       5.00        0.5      0.060     2001
# 44                         Toluene     150.00        0.5    150.000     1999
# 45          1,2,4-Trichlorobenzene       5.00        0.5      5.000     1999
# 46           1,1,1-Trichloroethane     200.00        0.5   1000.000     2006
# 47           1,1,2-Trichloroethane       5.00        0.5      0.300     2006
# 48                 Trichloroethene       5.00        0.5      1.700     2009
# 49          Trichlorofluoromethane     150.00        5.0   1300.000     2014
#
#     Federal_MCL  Federal_MCLG      Units
# 0           NaN           NaN       ug/L
# 1           6.0           6.0       ug/L
# 2          10.0           0.0       ug/L
# 3           7.0           7.0        MFL
# 4        2000.0        2000.0       ug/L
# 5           4.0           4.0       ug/L
# 6           5.0           5.0       ug/L
# 7         100.0         100.0       ug/L
# 8           0.2           0.2       mg/L
# 9           4.0           4.0       mg/L
# 10          2.0           2.0       ug/L
# 11          NaN           NaN       ug/L
# 12      10000.0       10000.0  mg/L as N
# 13       1000.0        1000.0  mg/L as N
# 14          NaN           NaN  mg/L as N
# 15          NaN           NaN       ug/L
# 16         50.0          50.0       ug/L
# 17          2.0           0.5       ug/L
# 18       1300.0        1300.0       ug/L
# 19         15.0           0.0       ug/L
# 20         22.5           0.0       ug/L
# 21          4.0           0.0    mrem/yr
# 22          7.5           0.0       ug/L
# 23          NaN           NaN       ug/L
# 24          NaN           NaN       ug/L
# 25         30.0           0.0       ug/L
# 26          5.0           0.0       ug/L
# 27          5.0           0.0       ug/L
# 28        600.0         600.0       ug/L
# 29         75.0          75.0       ug/L
# 30          NaN           NaN       ug/L
# 31          5.0           0.0       ug/L
# 32          7.0           7.0       ug/L
# 33         70.0          70.0       ug/L
# 34        100.0         100.0       ug/L
# 35          5.0           0.0       ug/L
# 36          5.0           0.0       ug/L
# 37          NaN           NaN       ug/L
# 38        700.0         700.0       ug/L
# 39          NaN           NaN       ug/L
# 40        100.0         100.0       ug/L
# 41        100.0         100.0       ug/L
# 42        100.0         100.0       ug/L
# 43          5.0           0.0       ug/L
# 44       1000.0        1000.0       ug/L
# 45         70.0          70.0       ug/L
# 46        200.0         200.0       ug/L
# 47          5.0           3.0       ug/L
# 48          5.0           0.0       ug/L
# 49          NaN           NaN       ug/L

# %%
Decontaminate(filename).tail(50)
# Out:
#                             Contaminant  State_MCL  State_DLR  State_PHG  \
# 41                              Styrene    100.000      0.500     0.5000
# 42            1,1,2,2-Tetrachloroethane      1.000      0.500     0.1000
# 43                    Tetrachloroethene      5.000      0.500     0.0600
# 44                              Toluene    150.000      0.500   150.0000
# 45               1,2,4-Trichlorobenzene      5.000      0.500     5.0000
# 46                1,1,1-Trichloroethane    200.000      0.500  1000.0000
# 47                1,1,2-Trichloroethane      5.000      0.500     0.3000
# 48                      Trichloroethene      5.000      0.500     1.7000
# 49               Trichlorofluoromethane    150.000      5.000  1300.0000
# 50       1,1,2-Trichlorotrifluoroethane   1200.000     10.000  4000.0000
# 51                       Vinyl chloride      0.500      0.500     0.0500
# 52                Total Xylene, (total)   1750.000      0.500  1800.0000
# 53                             Alachlor      2.000      1.000     4.0000
# 54                             Atrazine      1.000      0.500     0.1500
# 55                             Bentazon     18.000      2.000   200.0000
# 56                       Benzo(a)pyrene      0.200      0.100     0.0070
# 57                           Carbofuran     18.000      5.000     0.7000
# 58                            Chlordane      0.100      0.100     0.0300
# 59                              Dalapon    200.000     10.000   790.0000
# 60   1,2-Dibromo-3-chloropropane (DBCP)      0.200      0.010     0.0030
# 61                                2,4-D     70.000     10.000    20.0000
# 62            Bis(2-ethylhexyl) adipate    400.000      5.000   200.0000
# 63          bis(2-Ethylhexyl) phthalate      4.000      3.000    12.0000
# 64                       Dinoseb (DNPB)      7.000      2.000    14.0000
# 65                               Diquat     20.000      4.000     6.0000
# 66                             Endothal    100.000     45.000    94.0000
# 67                               Endrin      2.000      0.100     0.3000
# 68                   Ethylene Dibromide      0.050      0.020     0.0100
# 69                           Glyphosate    700.000     25.000   900.0000
# 70                           Heptachlor      0.010      0.010     0.0080
# 71                   Heptachlor epoxide      0.010      0.010     0.0060
# 72                    Hexachlorobenzene      1.000      0.500     0.0300
# 73            Hexachlorocyclopentadiene     50.000      1.000     2.0000
# 74                  BHC-gamma (Lindane)      0.200      0.200     0.0320
# 75                         Methoxychlor     30.000     10.000     0.0900
# 76                             Molinate     20.000      2.000     1.0000
# 77                               Oxamyl     50.000     20.000    26.0000
# 78              Pentachlorophenol (PCP)      1.000      0.200     0.3000
# 79                                PCB's    500.000      1.000   166.0000
# 80     Polychlorinated biphenyls (PCBs)      0.500      0.500     0.0900
# 81                             Simazine      4.000      1.000     4.0000
# 82                          Thiobencarb     70.000      1.000    42.0000
# 83                            Toxaphene      3.000      1.000     0.0300
# 84               1,2,3-Trichloropropane      0.005      0.005     0.0007
# 85  2,3,7,8-Tetrachlorodibenzo-p-dioxin     30.000      5.000     0.0500
# 86                    2,4,5-TP (Silvex)     50.000      1.000     3.0000
# 87                Total Trihalomethanes     80.000        NaN        NaN
# 88       Haloacetic Acids (five) (HAA5)     60.000        NaN        NaN
# 89                              Bromate     10.000      0.005     0.1000
# 90                             Chlorite   1000.000     20.000    50.0000
#
#    PHG_Date  Federal_MCL  Federal_MCLG Units
# 41     2010       100.00         100.0  ug/L
# 42     2003       100.00         100.0  ug/L
# 43     2001         5.00           0.0  ug/L
# 44     1999      1000.00        1000.0  ug/L
# 45     1999        70.00          70.0  ug/L
# 46     2006       200.00         200.0  ug/L
# 47     2006         5.00           3.0  ug/L
# 48     2009         5.00           0.0  ug/L
# 49     2014          NaN           NaN  ug/L
# 50     2011          NaN           NaN  ug/L
# 51     2000         2.00           0.0  ug/L
# 52     1997     10000.00       10000.0  ug/L
# 53     1997         2.00           0.0  ug/L
# 54     1999         3.00           3.0  ug/L
# 55     2009          NaN           NaN  ug/L
# 56     2010         0.20           0.0  ug/L
# 57     2016        40.00          40.0  ug/L
# 58     2006         2.00           0.0  ug/L
# 59     2009       200.00         200.0  ug/L
# 60     2020         0.20           0.0  ug/L
# 61     2009        70.00          70.0  ug/L
# 62     2003       400.00         400.0  ug/L
# 63     1997         6.00           0.0  ug/L
# 64     2010         7.00           7.0  ug/L
# 65     2016        20.00          20.0  ug/L
# 66     2014       100.00         100.0  ug/L
# 67     2016         2.00           2.0  ug/L
# 68     2003         0.05           0.0  ug/L
# 69     2007       700.00         700.0  ug/L
# 70     1999         0.40           0.0  ug/L
# 71     1999         0.20           0.0  ug/L
# 72     2003         1.00           0.0  ug/L
# 73     2014        50.00          50.0  ug/L
# 74     2005         0.20           0.2  ug/L
# 75     2010        40.00          40.0  ug/L
# 76     2008          NaN           NaN  ug/L
# 77     2009       200.00         200.0  ug/L
# 78     2009         1.00           0.0  ug/L
# 79     2016       500.00         500.0  ug/L
# 80     2007         0.50           0.0  ug/L
# 81     2001         4.00           4.0  ug/L
# 82     2016          NaN           NaN  ug/L
# 83     2003         3.00           0.0  ug/L
# 84     2009          NaN           NaN  ug/L
# 85     2010        30.00           0.0  pg/L
# 86     2014        50.00          50.0  ug/L
# 87      NaN        80.00           NaN  ug/L
# 88      NaN        60.00           NaN  ug/L
# 89     2009        10.00           0.0  ug/L
# 90     2009      1000.00         800.0  ug/L

# %% [markdown]
# The changes have been made with the latest addition of the Decontaminate_Names subroutine to the imported Decontaminate function.
#
# In this update, the units have been corrected to ug/L
#
# Since there is inconsistency among the lab results across time and the state, those adjustments will be made during the analysis.

# %%
write_file = Decontaminate(filename)

# %% [markdown]
# ### LATER UPDATE
# Now that I'm looking at the parameters from the state lab results, the naming convention is different in the collected data, but these are not unique rows like the regulatory sheet is, so I will be changing the naming conventions to match those of the collected data.
#
# To do this, each of the lists was alphabetically sorted in SQL. Since I only need to address those that are present in the state-regulatory material, I only need to scroll through the 435 rows of disinct labels in lab tests to verify the labeling of the 91 in the standards. Most of the convention issues are in the first few, as these are the chemical structures that have acronyms or abbreviations that are not present in the collected data.
#
# - Dichloroethylene and Dichloroethene are the same chemical structure, but use different naming conventions. The state regulations use the Dichloroethylene on their documentation, but the lab measurements use the naming Dichloroethene.
#
# Going to create a function that changes the chemical names that are problematic based on the output of this function, as not all of them were modified in the original Decontaminate_Values function.

# %% [markdown]
# ### Changes made:
# Many of the compounds and elements in the measurements were listed as Dissolved ____ or Total ____, so these were all changed. Several of the chemicals used a different chemical name for the same compound, and finally, a number of them did or did not include common names or just had slight formatting differences. Each of these was changed in a subroutine called Decontaminate_Names, which has been added as the final subroutine in the parent Decontaminate function.

# %%
write_file.to_csv(new_file, index=False)

# %% [markdown]
# Final step - will repopulate the SQL data with the new table
