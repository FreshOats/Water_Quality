# %%
from Decontaminate import Decontaminate
import numpy as np
import pandas as pd

# %%
filename = 'Data/mcls_dlrs_phgs.pdf'
new_file = 'Data/state_regulations.csv'

# %%
from tabula import read_pdf
from tabulate import tabulate
import pandas as pd
df_list = read_pdf(filename, pages='all')

# %%
df_list[1]
# Out:
#      State Regulated\rInorganic Chemical\rContaminant State\rMCL State\rDLR  \
# 0   Chromium,\rHexavalent - 0.01-\rmg/L MCL & 0.00...         --         --
# 1                                             Cyanide       0.15        0.1
# 2                                            Fluoride          2        0.1
# 3                                 Mercury (inorganic)      0.002      0.001
# 4                                              Nickel        0.1       0.01
# 5                           Nitrate (as nitrogen,\rN)    10 as N        0.4
# 6                                      Nitrite (as N)     1 as N        0.4
# 7                           Nitrate + Nitrite (as\rN)    10 as N         --
# 8                                         Perchlorate      0.006      0.002
# 9                                            Selenium       0.05      0.005
# 10                                           Thallium      0.002      0.001
#
#                 State PHG State\rDate of\rPHG Federal\rMCL Federal\rMCLG
# 0                 0.00002                2011           --            --
# 1                    0.15                1997          0.2           0.2
# 2                       1                1997          4.0           4.0
# 3                  0.0012    1999\r(rev2005)*        0.002         0.002
# 4                   0.012                2001           --            --
# 5   45 as NO3\r(=10 as N)                2018           10            10
# 6                  1 as N                2018            1             1
# 7                 10 as N                2018           --            --
# 8                   0.001                2015           --            --
# 9                    0.03                2010         0.05          0.05
# 10                 0.0001     1999\r(rev2004)        0.002        0.0005

# %%
df_list[11]
# Out:
#   State Regulated\rNon-Volatile\rSynthetic Organic\rContaminants  State\rMCL  \
# 0                  Polychlorinated\rbiphenyls (PCBs)                  0.0005
# 1                                           Simazine                   0.004
# 2                                        Thiobencarb                    0.07
# 3                                          Toxaphene                   0.003
# 4                           1,2,3-\rTrichloropropane              0.00000\r5
# 5                             2,3,7,8-TCDD\r(dioxin)                  3x10-8
# 6                                  2,4,5-TP (Silvex)                    0.05
#
#    State\rDLR  State PHG  State\rDate of\rPHG Federal\rMCL  Unnamed: 0  \
# 0      0.0005    0.00009                 2007       0.0005         NaN
# 1       0.001      0.004                 2001        0.004         NaN
# 2       0.001      0.042                 2016           --         NaN
# 3       0.001    0.00003                 2003        0.003         NaN
# 4  0.00000\r5  0.0000007                 2009           --         NaN
# 5      5x10-9    5x10-11                 2010       3x10-8         NaN
# 6       0.001      0.003                 2014         0.05         NaN
#
#   Federal\rMCLG
# 0          zero
# 1         0.004
# 2            --
# 3          zero
# 4            --
# 5          zero
# 6          0.05

# %%
Decontaminate(filename).head(50)
# Out:
#                        Contaminant   State_MCL  State_DLR   State_PHG  \
# 0               Dissolved Aluminum      1.0000     0.0500    0.600000
# 1               Dissolved Antimony      0.0060     0.0060    0.001000
# 2                Dissolved Arsenic      0.0100     0.0020    0.000004
# 3             Asbestos, Chrysotile      7.0000     0.2000    7.000000
# 4                 Dissolved Barium      1.0000     0.1000    2.000000
# 5              Dissolved Beryllium      0.0040     0.0010    0.001000
# 6                Dissolved Cadmium      0.0050     0.0010    0.000040
# 7                   Total Chromium      0.0500     0.0100         NaN
# 8                          Cyanide      0.1500     0.1000    0.150000
# 9               Dissolved Fluoride      2.0000     0.1000    1.000000
# 10               Dissolved Mercury      0.0020     0.0010    0.001200
# 11                Dissolved Nickel      0.1000     0.0100    0.012000
# 12               Dissolved Nitrate     10.0000     0.4000   45.000000
# 13               Dissolved Nitrite      1.0000     0.4000    1.000000
# 14     Dissolved Nitrate + Nitrite     10.0000        NaN   10.000000
# 15                     Perchlorate      0.0060     0.0020    0.001000
# 16              Dissolved Selenium      0.0500     0.0050    0.030000
# 17              Dissolved Thallium      0.0020     0.0010    0.000100
# 18                Dissolved Copper      1.3000     0.0500    0.300000
# 19                  Dissolved Lead      0.0150     0.0050    0.000200
# 20            Gross Alpha Particle     15.0000     3.0000         NaN
# 21             Gross Beta Particle      4.0000     4.0000         NaN
# 22         Radium-226 + Radium-228      5.0000        NaN         NaN
# 23             Dissolved Strontium      8.0000     2.0000    0.350000
# 24                         Tritium  20000.0000  1000.0000  400.000000
# 25               Dissolved Uranium     20.0000     1.0000    0.430000
# 26                         Benzene      0.0010     0.0005    0.000150
# 27            Carbon tetrachloride      0.0005     0.0005    0.000100
# 28             1,2-Dichlorobenzene      0.6000     0.0005    0.600000
# 29             1,4-Dichlorobenzene      0.0050     0.0005    0.006000
# 30              1,1-Dichloroethane      0.0050     0.0005    0.003000
# 31              1,2-Dichloroethane      0.0005     0.0005    0.000400
# 32              1,1-Dichloroethene      0.0060     0.0005    0.010000
# 33          cis-1,2-Dichloroethene      0.0060     0.0005    0.013000
# 34        trans-1,2-Dichloroethene      0.0100     0.0005    0.050000
# 35              Methylene chloride      0.0050     0.0005    0.004000
# 36             1,2-Dichloropropane      0.0050     0.0005    0.000500
# 37         cis-1,3-Dichloropropene      0.0005     0.0005    0.000200
# 38                    Ethylbenzene      0.3000     0.0005    0.300000
# 39  Methyl tert-butyl ether (MTBE)      0.0130     0.0030    0.013000
# 40                   Chlorobenzene      0.0700     0.0005    0.070000
# 41                         Styrene      0.1000     0.0005    0.000500
# 42       1,1,2,2-Tetrachloroethane      0.0010     0.0005    0.000100
# 43               Tetrachloroethene      0.0050     0.0005    0.000060
# 44                         Toluene      0.1500     0.0005    0.150000
# 45          1,2,4-Trichlorobenzene      0.0050     0.0005    0.005000
# 46           1,1,1-Trichloroethane      0.2000     0.0005    1.000000
# 47           1,1,2-Trichloroethane      0.0050     0.0005    0.000300
# 48                 Trichloroethene      0.0050     0.0005    0.001700
# 49          Trichlorofluoromethane      0.1500     0.0050    1.300000
#
#    PHG_Date  Federal_MCL  Federal_MCLG                         Units
# 0      2001          NaN           NaN                          mg/L
# 1      2016        0.006        0.0060                          mg/L
# 2      2004        0.010        0.0000                          mg/L
# 3      2003        7.000        7.0000                           MFL
# 4      2003        2.000        2.0000                          mg/L
# 5      2003        0.004        0.0040                          mg/L
# 6      2006        0.005        0.0050                          mg/L
# 7      1999        0.100        0.1000                          mg/L
# 8      1997        0.200        0.2000                          mg/L
# 9      1997        4.000        4.0000                          mg/L
# 10     2005        0.002        0.0020                          mg/L
# 11     2001          NaN           NaN                          mg/L
# 12     2018       10.000       10.0000                  10 as N mg/L
# 13     2018        1.000        1.0000                   1 as N mg/L
# 14     2018          NaN           NaN                  10 as N mg/L
# 15     2015          NaN           NaN                          mg/L
# 16     2010        0.050        0.0500                          mg/L
# 17     2004        0.002        0.0005                          mg/L
# 18     2008        1.300        1.3000                          mg/L
# 19     2009        0.015        0.0000                          mg/L
# 20      NaN       15.000        0.0000                         pCi/L
# 21      NaN        4.000        0.0000                         pCi/L
# 22      NaN        5.000        0.0000                         pCi/L
# 23     2006          NaN           NaN                         pCi/L
# 24     2006          NaN           NaN                         pCi/L
# 25     2001       30.000        0.0000  pCi/L (ug/L for Federal_MCL)
# 26     2001        0.005        0.0000                          mg/L
# 27     2000        0.005        0.0000                          mg/L
# 28     2009        0.600        0.6000                          mg/L
# 29     1997        0.075        0.0750                          mg/L
# 30     2003          NaN           NaN                          mg/L
# 31     2005        0.005        0.0000                          mg/L
# 32     1999        0.007        0.0070                          mg/L
# 33     2018        0.070        0.0700                          mg/L
# 34     2018        0.100        0.1000                          mg/L
# 35     2000        0.005        0.0000                          mg/L
# 36     1999        0.005        0.0000                          mg/L
# 37     2006          NaN           NaN                          mg/L
# 38     1997        0.700        0.7000                          mg/L
# 39     1999          NaN           NaN                          mg/L
# 40     2014        0.100        0.1000                          mg/L
# 41     2010        0.100        0.1000                          mg/L
# 42     2003        0.100        0.1000                          mg/L
# 43     2001        0.005        0.0000                          mg/L
# 44     1999        1.000        1.0000                          mg/L
# 45     1999        0.070        0.0700                          mg/L
# 46     2006        0.200        0.2000                          mg/L
# 47     2006        0.005        0.0030                          mg/L
# 48     2009        0.005        0.0000                          mg/L
# 49     2014          NaN           NaN                          mg/L

# %% [markdown]
# The changes have been made with the latest addition of the Decontaminate_Names subroutine to the imported Decontaminate function.

# %%
write_file = Decontaminate(filename)

# %% [markdown]
# ### LATER UPDATE
# Now that I'm looking at the parameters from the state lab results, the naming convention is different in the collected data, but these are not unique rows like the regulatory sheet is, so I will be changing the naming conventions to match those of the collected data.
#
# To do this, each of the lists was alphabetically sorted in SQL. Since I only need to address those that are present in the state-regulatory material, I only need to scroll through the 435 rows of disinct labels in lab tests to verify the labeling of the 91 in the standards. Most of the convention issues are in the first few, as these are the chemical structures that have acronyms or abbreviations that are not present in the collected data.
#
# - Dichloroethylene and Dichloroethene are the same chemical structure, but use different naming conventions. The state regulations use the Dichloroethylene on their documentation, but the lab measurements use the naming Dichloroethene.
#
# Going to create a function that changes the chemical names that are problematic based on the output of this function, as not all of them were modified in the original Decontaminate_Values function.

# %% [markdown]
# ### Changes made:
# Many of the compounds and elements in the measurements were listed as Dissolved ____ or Total ____, so these were all changed. Several of the chemicals used a different chemical name for the same compound, and finally, a number of them did or did not include common names or just had slight formatting differences. Each of these was changed in a subroutine called Decontaminate_Names, which has been added as the final subroutine in the parent Decontaminate function.

# %%
write_file.to_csv(new_file, index=False)
