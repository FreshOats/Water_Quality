# %%
from Decontaminate import Decontaminate
import numpy as np

# %%
filename = 'Data/mcls_dlrs_phgs.pdf'

# %%
Decontaminate(filename)
# Out:
#                        Contaminant  State_MCL  State_DLR  State_PHG PHG_Date  \
# 0                         Aluminum      1.000      0.050   0.600000     2001
# 1                         Antimony      0.006      0.006   0.001000     2016
# 2                          Arsenic      0.010      0.002   0.000004     2004
# 3                         Asbestos      7.000      0.200   7.000000     2003
# 4                           Barium      1.000      0.100   2.000000     2003
# ..                             ...        ...        ...        ...      ...
# 87               2,4,5-TP (Silvex)      0.050      0.001   0.003000     2014
# 88           Total Trihalomethanes      0.080        NaN        NaN      NaN
# 89  Haloacetic Acids (five) (HAA5)      0.060        NaN        NaN      NaN
# 90                         Bromate      0.010      0.005   0.000100     2009
# 91                        Chlorite      1.000      0.020   0.050000     2009
#
#     Federal_MCL  Federal_MCLG Units
# ...
