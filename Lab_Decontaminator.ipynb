# %% [markdown]
# # Units analysis on the collected water data

# %%
import pandas as pd
import numpy as np
import re

# %%
labs = pd.read_csv("data/lab_results.csv")
standards = pd.read_csv("data/state_regulations.csv")

# %%
labs.head()
# Out:
#    station_id   station_name full_station_name station_number station_type  \
# 0        8135  01S04E32C001M     01S04E32C001M  01S04E32C001M  Groundwater
# 1        8135  01S04E32C001M     01S04E32C001M  01S04E32C001M  Groundwater
# 2        8135  01S04E32C001M     01S04E32C001M  01S04E32C001M  Groundwater
# 3        8135  01S04E32C001M     01S04E32C001M  01S04E32C001M  Groundwater
# 4        8135  01S04E32C001M     01S04E32C001M  01S04E32C001M  Groundwater
#
#    latitude  longitude                 status county_name   sample_code  \
# 0   37.8073   121.5617  Review Status Unknown     Alameda  WDIS_0719152
# 1   37.8073   121.5617  Review Status Unknown     Alameda  WDIS_0719152
# 2   37.8073   121.5617  Review Status Unknown     Alameda  WDIS_0719152
# 3   37.8073   121.5617  Review Status Unknown     Alameda  WDIS_0719152
# 4   37.8073   121.5617  Review Status Unknown     Alameda  WDIS_0719152
#
#         sample_date  sample_depth sample_depth_units            parameter  \
# 0  05/03/1967 09:00           NaN               Feet          Conductance
# 1  05/03/1967 09:00           NaN               Feet      Dissolved Boron
# 2  05/03/1967 09:00           NaN               Feet    Dissolved Calcium
# 3  05/03/1967 09:00           NaN               Feet   Dissolved Chloride
# 4  05/03/1967 09:00           NaN               Feet  Dissolved Magnesium
#
#    result  reporting_limit  units            method_name
# 0  3480.0              1.0  uS/cm              EPA 120.1
# 1     7.7              0.1   mg/L   Std Method 4500-B, C
# 2    68.0              1.0   mg/L              EPA 215.2
# 3   758.0              0.1   mg/L  Std Method 4500-Cl, B
# 4    59.0              0.1   mg/L  Std Method 3500-Mg, E

# %%
standards.head()
# Out:
#   Contaminant  State_MCL  State_DLR  State_PHG  PHG_Date  Federal_MCL  \
# 0    Aluminum      1.000      0.050   0.600000    2001.0          NaN
# 1    Antimony      0.006      0.006   0.001000    2016.0        0.006
# 2     Arsenic      0.010      0.002   0.000004    2004.0        0.010
# 3    Asbestos      7.000      0.200   7.000000    2003.0        7.000
# 4      Barium      1.000      0.100   2.000000    2003.0        2.000
#
#    Federal_MCLG Units
# 0           NaN  mg/L
# 1         0.006  mg/L
# 2         0.000  mg/L
# 3         7.000   MFL
# 4         2.000  mg/L

# %% [markdown]
# ## Unit Analysis
#
# - The State Standads have most of the units listed in mg/L, except in some cases, however not all of the contaminants listed have the same units
# - There are more parameters tested in the lab than just contaminants, we only want to compare contaminants in this case
# - There are some discrepancies in the contaminant name vs the parameter name in the labs table
#
# Thoughts:
# - A lot of the columns can be dropped from the labs table to reduce the size of the data
#     - Are all station_name, full_station_name, and station_number the same?
#     - Status, sample_code, sample_date, sample_depth, sample_depth_units, reporting_limit, and method_name are unnecessary
#
# - I don't need to add all of the columns from the standards table to the labs
#     - Contaminant, state_mcl, federal_mcl and units are required
#
# - I need to add a column for measurement type
#     - Contaminants will be listed as contaminants
#     - Others include physical attributes such as turbidity and odor
#     - Electrochemical - conductance and pH
#     - Non-contaminants such as minerals and other elements?

# %%
len(labs['parameter'].unique())
# Out:
# 435

# %% [markdown]
# Unfortunately, that's a lot. Taking a look at the first 25.

# %%
top50 = labs.parameter.sort_values().unique()[0:50]

# %%
top50
# Out:
# array(['(Aminomethyl)phosphonic acid',
#        '*No Lab Analyses (Field Measures Only)',
#        '1,1,1,2-Tetrachloroethane', '1,1,1-Trichloroethane',
#        '1,1,2,2-Tetrachloroethane', '1,1,2-Trichloroethane',
#        '1,1,2-Trichlorotrifluoroethane', '1,1-Dichloroethane',
#        '1,1-Dichloroethene', '1,1-Dichloropropene',
#        '1,2,3-Trichlorobenzene', '1,2,3-Trichloropropane',
#        '1,2,4-Trichlorobenzene', '1,2,4-Trimethylbenzene',
#        '1,2-Dibromo-3-chloropropane (DBCP)', '1,2-Dibromoethane (EDB)',
#        '1,2-Dichlorobenzene', '1,2-Dichloroethane', '1,2-Dichloropropane',
#        '1,3,5-Trimethylbenzene', '1,3-Dichlorobenzene',
#        '1,3-Dichloropropane', '1,4-Dichlorobenzene', '1-Naphthol',
#        '100-Day Biochemical Oxygen Demand', '2,2-Dichloropropane',
#        '2,3,6-Trichlorobenzoic Acid',
#        '2,3,7,8-Tetrachlorodibenzo-p-dioxin', '2,3-Dibromopropionic acid',
#        '2,4,5-T', '2,4,5-TP (Silvex)', '2,4-D', '2,4-DB',
#        '2-Chloroallyl diethyldithiocarbamate (CDEC)', '2-Chlorotoluene',
#        '3,5-Dichlorobenzoic Acid', '3-Hydroxycarbofuran',
#        "4,4'-Dibromoctafluorobiphenyl", '4-Bromofluorobenzene',
#        '4-Chlorotoluene', '4-Day Biochemical Oxygen Demand',
#        '4-Isopropyltoluene', '4-Nitrophenol',
#        '5-Day Biochemical Oxygen Demand',
#        '6-Day Biochemical Oxygen Demand',
#        '7-Day Biochemical Oxygen Demand', 'Acenaphthene',
#        'Acenaphthylene', 'Acephate', 'Acifluorfen'], dtype=object)

# %%
standards
# Out:
#                        Contaminant  State_MCL  State_DLR  State_PHG  PHG_Date  \
# 0                         Aluminum      1.000      0.050   0.600000    2001.0
# 1                         Antimony      0.006      0.006   0.001000    2016.0
# 2                          Arsenic      0.010      0.002   0.000004    2004.0
# 3                         Asbestos      7.000      0.200   7.000000    2003.0
# 4                           Barium      1.000      0.100   2.000000    2003.0
# ..                             ...        ...        ...        ...       ...
# 86               2,4,5-TP (Silvex)      0.050      0.001   0.003000    2014.0
# 87           Total Trihalomethanes      0.080        NaN        NaN       NaN
# 88  Haloacetic Acids (five) (HAA5)      0.060        NaN        NaN       NaN
# 89                         Bromate      0.010      0.005   0.000100    2009.0
# 90                        Chlorite      1.000      0.020   0.050000    2009.0
#
#     Federal_MCL  Federal_MCLG Units
# 0           NaN           NaN  mg/L
# 1         0.006         0.006  mg/L
# 2         0.010         0.000  mg/L
# 3         7.000         7.000   MFL
# 4         2.000         2.000  mg/L
# ..          ...           ...   ...
# 86        0.050         0.050  mg/L
# 87        0.080           NaN  mg/L
# 88        0.060           NaN  mg/L
# 89        0.010         0.000  mg/L
# 90        1.000         0.800  mg/L
#
# [91 rows x 8 columns]

# %%
x
# Out:
# []
