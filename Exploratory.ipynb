# %%
import pandas as pd
import numpy as np

# %%
field = pd.read_csv("field_results.csv")
field.head()
# Out:
# C:\Users\justi\AppData\Local\Temp\ipykernel_17396\1398289693.py:1: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   field = pd.read_csv("field_results.csv")
#    station_id          station_name station_number  \
# 0          12  H.O. Banks Headworks       KA000331
# 1          12  H.O. Banks Headworks       KA000331
# 2          12  H.O. Banks Headworks       KA000331
# 3          12  H.O. Banks Headworks       KA000331
# 4          12  H.O. Banks Headworks       KA000331
#
#                        full_station_name   station_type  latitude  longitude  \
# 0  Delta P.P. Headworks at H.O. Banks PP  Surface Water   37.8019   121.6203
# 1  Delta P.P. Headworks at H.O. Banks PP  Surface Water   37.8019   121.6203
# 2  Delta P.P. Headworks at H.O. Banks PP  Surface Water   37.8019   121.6203
# 3  Delta P.P. Headworks at H.O. Banks PP  Surface Water   37.8019   121.6203
# ...

# %%
field.dtypes
# Out:
# station_id               int64
# station_name            object
# station_number          object
# full_station_name       object
# station_type            object
# latitude               float64
# longitude              float64
# status                  object
# county_name             object
# sample_code             object
# sample_date             object
# sample_depth           float64
# sample_depth_units      object
# anl_data_type           object
# parameter               object
# fdr_result             float64
# fdr_text_result         object
# fdr_date_result         object
# fdr_reporting_limit    float64
# uns_name                object
# mth_name                object
# fdr_footnote            object
# dtype: object

# %%
field.columns
# Out:
# Index(['station_id', 'station_name', 'station_number', 'full_station_name',
#        'station_type', 'latitude', 'longitude', 'status', 'county_name',
#        'sample_code', 'sample_date', 'sample_depth', 'sample_depth_units',
#        'anl_data_type', 'parameter', 'fdr_result', 'fdr_text_result',
#        'fdr_date_result', 'fdr_reporting_limit', 'uns_name', 'mth_name',
#        'fdr_footnote'],
#       dtype='object')

# %%
picks = field[field['station_id'] == 47928]

picks
# Out:
#        station_id         station_name station_number  \
# 55658       47928  LkOro SF-subsurface       OR997000
# 55659       47928  LkOro SF-subsurface       OR997000
# 55660       47928  LkOro SF-subsurface       OR997000
# 55661       47928  LkOro SF-subsurface       OR997000
# 55662       47928  LkOro SF-subsurface       OR997000
# 55663       47928  LkOro SF-subsurface       OR997000
# 55664       47928  LkOro SF-subsurface       OR997000
# 55665       47928  LkOro SF-subsurface       OR997000
# 55666       47928  LkOro SF-subsurface       OR997000
# 55667       47928  LkOro SF-subsurface       OR997000
# 55668       47928  LkOro SF-subsurface       OR997000
# 55669       47928  LkOro SF-subsurface       OR997000
# 55670       47928  LkOro SF-subsurface       OR997000
# 55671       47928  LkOro SF-subsurface       OR997000
# 55672       47928  LkOro SF-subsurface       OR997000
# 55673       47928  LkOro SF-subsurface       OR997000
# ...

# %%
no_notes = field.drop('fdr_footnote', axis=1)

# %%
no_notes.head()

# station_id', 'station_name', 'station_number', 'full_station_name',
# 'station_type', 'latitude', 'longitude', 'status', 'county_name',
# 'sample_code', 'sample_date', 'sample_depth', 'sample_depth_units',
# 'anl_data_type', 'parameter', 'fdr_result', 'fdr_text_result',
# 'fdr_date_result', 'fdr_reporting_limit', 'uns_name', 'mth_name',
# 'fdr_footnote'
# Out:
#    station_id          station_name station_number  \
# 0          12  H.O. Banks Headworks       KA000331
# 1          12  H.O. Banks Headworks       KA000331
# 2          12  H.O. Banks Headworks       KA000331
# 3          12  H.O. Banks Headworks       KA000331
# 4          12  H.O. Banks Headworks       KA000331
#
#                        full_station_name   station_type  latitude  longitude  \
# 0  Delta P.P. Headworks at H.O. Banks PP  Surface Water   37.8019   121.6203
# 1  Delta P.P. Headworks at H.O. Banks PP  Surface Water   37.8019   121.6203
# 2  Delta P.P. Headworks at H.O. Banks PP  Surface Water   37.8019   121.6203
# 3  Delta P.P. Headworks at H.O. Banks PP  Surface Water   37.8019   121.6203
# 4  Delta P.P. Headworks at H.O. Banks PP  Surface Water   37.8019   121.6203
#
#                   status county_name  sample_code  ... sample_depth  \
# 0  Review Status Unknown     Alameda  OM0168A0001  ...          1.0
# ...

# %%
field.station_type.str.len().max()
# Out:
# 13

# %%
no_notes.to_csv("field_results_no_footnotes.csv")

# %%
no_notes
# Out:
#          station_id          station_name station_number  \
# 0                12  H.O. Banks Headworks       KA000331
# 1                12  H.O. Banks Headworks       KA000331
# 2                12  H.O. Banks Headworks       KA000331
# 3                12  H.O. Banks Headworks       KA000331
# 4                12  H.O. Banks Headworks       KA000331
# ...             ...                   ...            ...
# 1152955       47584           YCWA PMW-29  16N04E02A001M
# 1152956       47584           YCWA PMW-29  16N04E02A001M
# 1152957       47584           YCWA PMW-29  16N04E02A001M
# 1152958       47584           YCWA PMW-29  16N04E02A001M
# 1152959       47584           YCWA PMW-29  16N04E02A001M
#
#                              full_station_name   station_type   latitude  \
# 0        Delta P.P. Headworks at H.O. Banks PP  Surface Water  37.801900
# 1        Delta P.P. Headworks at H.O. Banks PP  Surface Water  37.801900
# ...
